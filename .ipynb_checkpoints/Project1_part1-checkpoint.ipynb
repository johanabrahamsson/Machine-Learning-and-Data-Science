# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from skimage.transform import rescale, resize
import imageio
import random
random.seed(0)

def read_image(name):
    image_read = imageio.imread(name)
    image_read = resize(image_read,(128,128))
    image_read = 255 * image_read
    image_read = image_read.astype(np.uint8)
    data = image_read.ravel()
    return image_read, data
    
def show_image(image_show):
    image_show = np.array([image_show])
    image_show = np.reshape(image_show, (128,128))
    image_show = resize(image_show,(128,128))
    plt.imshow(image_show, cmap=cm.gray)
    plt.show()
    
def add_noise(data):
    mean = 0
    variance = 20
    gauss = np.random.normal(mean, variance, len(data))
    data_noise = data + gauss
    data_noise[data > 255] = 255
    data_noise[data < 0] = 0
    return data_noise

def ICM(data, noisy_image, lam):
    image1 = np.reshape(data, (128,128))
    noisy_image = np.reshape(noisy_image, (128,128))
    for row in range(image1.shape[0]):
        for col in range(image1.shape[1]):
            image1[row,col] = min_energy(noisy_image, image1, row, col, lam)
    return image1
            
def min_energy(noisy_image, image1, row, col, lam):
    pixel = noisy_image[row,col]
    if row > 0:
        pixel += lam*image1[row-1,col]
    if col > 0:
        pixel += lam*image1[row,col-1]
    if col < image1.shape[1]-1:
        pixel += lam*image1[row,col+1]
    if row < image1.shape[0]-1:
        pixel += lam*image1[row+1,col]
    pixel = pixel/(1+4*lam)
    if pixel > 255:
        pixel = 255
    return pixel

def MSE(denoised_image, image_no_noise):
    image_no_noise = np.array([image_no_noise])
    image_no_noise = image_no_noise.reshape(128,128)
    mse = ((denoised_image - image_no_noise)**2).mean(axis=None)
    return mse

if __name__=="__main__":
    name="/Users/johanabrahamsson/Documents/Machine learning and data science/Python/lena_gray.jpg"
    min_lambda = 0.1
    max_lambda = 10
    length = int(max_lambda/min_lambda)
    lam_vec = np.linspace(min_lambda, max_lambda, length)
    mse_vec = np.zeros((1,length))
    denoised_image_mat = np.zeros((128,128,length))
    image_no_noise, data = read_image(name)
    noisy_image = add_noise(data)
    denoised_image = ICM(data, noisy_image, 5)
    image_no_noise2, data2 = read_image(name)
    show_image(image_no_noise2)
    show_image(noisy_image)
    show_image(denoised_image)
    mse = MSE(denoised_image,image_no_noise2)
    print(mse)

    
    """
    image_no_noise, data = read_image(name)
    noisy_image2 = add_noise(data)
    #show_image(noisy_image)
    #show_image(denoised_image)
    #mse = MSE(denoised_image, image_no_noise2)
    #print(mse)
    #noisy_image_mat = np.zeros((length, len(data)))
    for i in range(len(lam_vec)):
        denoised_image = ICM(data, noisy_image2, lam_vec[i])
        denoised_image_mat[:,:,i] = denoised_image
        image_no_noise3, data3 = read_image(name)
        mse = MSE(denoised_image, image_no_noise3)
        mse_vec[:,i] = mse
        #print(mse)
    print(mse_vec[:,np.argmin(mse_vec)], lam_vec[np.argmin(mse_vec)])
    image_no_noise4, data4 = read_image(name)
    show_image(image_no_noise4)
    show_image(noisy_image2)
    show_image(denoised_image_mat[:,:,np.argmin(mse_vec)])
    """
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# 47.65631103515625
